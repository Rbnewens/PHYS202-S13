# %%
t=arange(0.0, 1.0+0.01, 0.01)
s= cos(2*2*pi*t)
c= sin(2*2*pi*t)

# %%
fig = plot(t, s, "blue", linewidth=2.5)
plot(t, c, "red", linewidth=2.5)
xlabel('time(s)')
ylabel('voltage(mV)')
#add title for convenience
title('A Simple Plot', fontsize=20)
gride(True)
legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-21309bc488bc> in <module>()
#       5 #add title for convenience
#       6 title('A Simple Plot', fontsize=20)
# ----> 7 gride(True)
#       8 legend()
#
# NameError: name 'gride' is not defined
