# %%
import numpy.random

# %%
print numpy.random.random(5)
# Out:
# [ 0.83714909  0.8147861   0.50121395  0.498928    0.80242952]

# %%
print numpy.random.random(5)
# Out:
# [ 0.25362424  0.13632101  0.26685393  0.90566601  0.23258968]

# %%
numpy.random.seed(4242)
#print 5 random number from the generator with this seed
print "Using seed = 4242:"
print numpy.random.random(5)
# Out:
# Using seed = 4242:
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %%
#restore the seed to it's original 'None"
numpy.random.seed(None)
#print 5 more numbers using the new random seed
print "using seed = None:"
print numpy.random.random(5)
# Out:
# using seed = None:
# [ 0.66453025  0.7466527   0.4095738   0.5944324   0.74567763]

# %%
#reset the seed to 4242 and print again
numpy.random.seed(4242)
print "using seed = 4242, we should get the same numbers as before"
print numpy.random.random(5)
# Out:
# using seed = 4242, we should get the same numbers as before
# [ 0.32494949  0.94041458  0.91400794  0.28650938  0.78180262]

# %% [markdown]
# Example 1: Analytic Inverse CDF Transform

# %%
x = arange(0.,pi+0.001,0.01)
f = lambda x: sin(x)/2.
F = lambda x: (cos(0)-cos(x))/2.
    
plot(x,f(x),label='True distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(0,3.5)
ylim(0,1.1)

legend(loc=0)
show()

# %% [markdown]
# F-1(z) = cos-1(cos(0)-2z)

# %%
#number of samples
N = 10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: arccos(cos(0)-2*z)
    
#sampled x values
xsamples = Finv(z);

#how do they complre to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,pi)
ylim(0,0.7)

legend(loc=0)
show()

# %% [markdown]
# Exercise 1. Exponential function -analytic

# %%
x = arange(-10.,10.+0.001,0.01)
f = lambda x: exp(-x)
F = lambda x: -exp(-x)+1
    
plot(x,f(x),label='True distribution',lw=3)
plot(x,F(x),label='Cumulative function',lw=3)

xlim(-5.,5.)
ylim(-100.,100.)

legend(loc=0)
show()

# %%
#number of samples
N = 10000

#N random numbers between 0 and 1
z = numpy.random.random_sample(N);

#inverse CDF
Finv = lambda z: -log(1-z)#need inverse CDF function
    
#sampled x values
xsamples = Finv(z);

#how do they compare to the original?
hist(xsamples,50,normed=True,label="Sampled distribution")
plot(x,f(x),label='True distribution',lw=3,color='red')

xlim(0,5)
ylim(0,1)

legend(loc=0)
show()

# %%
# Out:
# no Python documentation found for 'ln'
