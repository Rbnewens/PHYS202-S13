# %% [markdown]
# Electric Dipole Potential

# %% [markdown]
# \begin{equation}
# V(x,y) = \frac{kq}{\sqrt{x^2 + (y-d)^2}} - \frac{kq}{\sqrt{x^2 + (y+d)^2}}
# \end{equation}

# %%
#make the x-y grid to cover the plane -2<x<2 and -2<y<2
dx = 0.06
dy = 0.06
x,y = meshgrid(arange(-2.,2.,dx),arange(-2.,2.,dy))

x.ndim
y.shape
# Out:
# (67, 67)

# %%
x.ndim
# Out:
# 2

# %%
k = 1; q = 1; d = 1
V = (k*q/(x**2+(y-d)**2)**(1/2.)) - (k*q/(x**2+(y+d)**2)**(1/2.))
print V
# Out:
# [[-0.1698635  -0.17826925 -0.18715865 ..., -0.19336737 -0.18414007
#   -0.17541494]
#  [-0.17127992 -0.17998007 -0.18920149 ..., -0.19565471 -0.18606779
#   -0.17702367]
#  [-0.17245961 -0.18144664 -0.19099347 ..., -0.19768747 -0.18774672
#   -0.17839056]
#  ...,
#  [ 0.17310174  0.18227437  0.19203282 ...,  0.19888408  0.18871243
#    0.17915368]
#  [ 0.17209427  0.1809867   0.19042599 ...,  0.19704029  0.18721662
#    0.1779635 ]
#  [ 0.17083282  0.17943553  0.18854686 ...,  0.19491887  0.18545135
#    0.17651294]]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V, rstride=4, cstride=1, linewidth=0,cmap=cm.Greys)
                    
cb = fig.colorbar(p, shrink=0.5)
cset = ax.contour(x, y, V, zdir='z', offset=-40., cmap=cm.coolwarm)
cset = ax.contour(x, y, V, zdir='x', offset=-2., cmap=cm.coolwarm)
#cset = ax.contour(x, y, V, zdir='y', offset=2., cmap=cm.coolwarm)

# %%
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -6, -8])
contour(x,y,V,levels,cmap=cm.gist_earth)
show()

# %% [markdown]
# Ex1. Make a 3-D plot of the function
# \begin{equation} G(x,y) = \exp(-x^2-y^2) \end{equation}
# over the range -6 < (x,y) < 6 using 51 bins in x and 51 bins in y

# %%
dx = 0.05
dy = 0.05
x,y = meshgrid(arange(-6.,6.,dx),arange(-6.,6.,dy))
G = exp(-x**2 - y**2)
fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, G, rstride=4, cstride=1, linewidth=0,cmap=cm.Greys)
                    
cb = fig.colorbar(p, shrink=0.5)
cset = ax.contour(x, y, G, zdir='z', offset=-40., cmap=cm.coolwarm)
cset = ax.contour(x, y, G, zdir='x', offset=-2., cmap=cm.coolwarm)

# %% [markdown]
# Ex2: Determine the eletric potential for a quadrupole consisting of q=-1.0 nC at both (x=+-2, y=0), and q=+1.0 nC at both (x=0,y=+-2). Make a surface plot and a contour plot on the range -4<x,y<4 using 101 bins in x and 101 bins in y.

# %%
k = 2; q = 1; d = 3
x,y = meshgrid(arange(-4.,4.,dx),arange(-4.,4.,dy))
V = (k*q/(x**2+(y-d)**2)**(1/2.)) - (k*q/(x**2+(y+d)**2)**(1/2.))

fig = figure()
ax = fig.gca(projection='3d')
p = ax.plot_surface(x, y, V, rstride=4, cstride=1, linewidth=0,cmap=cm.Greys)
#x,y = meshg.,6.,dx),arange(-6.,6.,dy))                    
cb = fig.colorbar(p, shrink=0.5)
cset = ax.contour(x, y, V, zdir='z', offset=-40., cmap=cm.coolwarm)
cset = ax.contour(x, y, V, zdir='x', offset=-2., cmap=cm.coolwarm)
cset = ax.contour(x, y, V, zdir='y', offset=2., cmap=cm.coolwarm)

# %%
levels = array([8, 4, 2, 1, 0.5, 0.25, 0, -0.25, -0.5, -1, -2, -4, -6, -8])
contour(x,y,V,levels,cmap=cm.gist_earth)
show()

# %% [markdown]
# Question 3

# %%
def pointPotential(X,Y,q,posx,posy):
        """Gives Vxy when given origin point (x,y) and location (posx, posy)"""
        Vxy=(8.89.e9)*q/sqrt((X-posx)**2. + (Y-posy)**2.)
        return Vxy

# %%
def dipolePotential(x,y,q,posx,angle):
        k = 8.9.e-9
        Vxy = (k*q/(x**2+(y-d)**2)**(1/2.)) - (k*q/(x**2+(y+d)**2)**(1/2.))
        return Vxy
