# %%
from Electrostatis import *

# %%
dx = .01
dy = .01
X,Y = meshgrid(arange(-0.1, 0.1, dx),arange(-0.1,0.1, dy))
p1 = pointPotential(X,Y,-2.,0.,-5.)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-cc86cc89a9be> in <module>()
#       2 dy = .01
#       3 X,Y = meshgrid(arange(-0.1, 0.1, dx),arange(-0.1,0.1, dy))
# ----> 4 p1 = pointPotential(X,Y,-2.,0.,-5.)
#
# /Network/Servers/cp-file-home.cp-calpoly.edu/studentHome$/user/rbnewens/PHYS202-S13/Week4/Electrostatis.py in pointPotential(X, Y, q, posx, posy)
#       3 def pointPotential(X,Y,q,posx,posy):
#       4         """Gives Vxy when given origin point (x,y) and location (posx, posy)"""
# ----> 5         Vxy=(8.89.e9)*q/sqrt((X-posx)**2. + (Y-posy)**2.)
#       6         return Vxy
#       7
#
# AttributeError: 'float' object has no attribute 'e9'

# %% [markdown]
# More Notes

# %% [markdown]
# Using Boolean masks to find data

# %%
theta = arange(0,2*pi+0.1,pi/100)
plot(theta,sin(theta))
show()

# %%
mask = (sin(theta)>0) & (sin(theta)<0.5)
#print mask
plot(theta,sin(theta),theta[mask],sin(theta[mask]))
show()

# %%
y = sin(theta[mask])
jj = (y == max(y))
y[jj] = NaN

# %%
plot(theta,sin(theta))
plot(theta[mask],y,linewidth=4)
show()
#boolean mask to find particular data

# %% [markdown]
# Interpolation

# %%
theta = arange(0.,2*pi+0.1,pi/10)
mask = (theta == 0.5)
#print mask

# %%
newTheta = 0.5; newSin = 0.
from scipy.interpolate import interp1d
sinInterp = interp1d(theta, sin(theta))

newSin = sinInterp(newTheta)
print newSin
# Out:
# 0.473922198704

# %%
plot(theta,sin(theta),newTheta,newSin, 'r+',markersize=20,markeredgewidth=3)
# Out:
# [<matplotlib.lines.Line2D at 0x10a802850>,
#  <matplotlib.lines.Line2D at 0x10a802d10>]

# %%
thetaNew = arange(0,2*pi,pi/30)
sinNew = interp1d(theta,sin(theta))(thetaNew)
plot(theta, sin(theta), thetaNew, sinNew, 'r.')
show()

# %%
plot(thetaNew, sinNew - sin(thetaNew))
ylabel('differece between interp and exact value')
show()

# %%
sinNewC = interp1d(theta, sin(theta), kind='cubic')(thetaNew)
subplot(2,1,1)
plot(thetaNew,sinNew-sin(thetaNew), thetaNew, sinNewC - sin(thetaNew), 'r')
subplot(2,1,2)
plot(thetaNew, sinNewC - sin(thetaNew), 'r')
show()
